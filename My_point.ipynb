# %%
import pandas as pd
data=pd.read_excel('My_point.xlsx')
data
# Out:
#                                  Unnamed: 0 Unnamed: 1        Unnamed: 2  \
# 0                                       NaN        NaN               NaN
# 1                                    Fənlər     Kredit  İmtahandan əvvəl
# 2                    Sistem proqramlaşdırma          7                46
# 3                                       HPC          8                48
# 4                                   Fəlsəfə          3                49
# 5                       Web texnologiyaları          4                48
# 6  Ehtimal nəzəriyyəsi və riyazi statistika          4                35
# 7            Paralel paylanmış hesablamalar          4                35
#
#          Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  Unnamed: 7
# 0               NaN        NaN        NaN        NaN         NaN
# 1  İmtahandan sonra      Yekun     Hərflə   Ortalama  Stipendiya
# 2                45         91          A      21.23    Zerbechi
# ...

# %%
data.dropna(subset='Unnamed: 0',inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7 entries, 1 to 7
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  7 non-null      object
#  1   Unnamed: 1  7 non-null      object
#  2   Unnamed: 2  7 non-null      object
#  3   Unnamed: 3  7 non-null      object
#  4   Unnamed: 4  7 non-null      object
#  5   Unnamed: 5  7 non-null      object
#  6   Unnamed: 6  7 non-null      object
#  7   Unnamed: 7  7 non-null      object
# dtypes: object(8)
# memory usage: 504.0+ bytes

# %%
data
# Out:
#                                  Unnamed: 0 Unnamed: 1        Unnamed: 2  \
# 1                                    Fənlər     Kredit  İmtahandan əvvəl
# 2                    Sistem proqramlaşdırma          7                46
# 3                                       HPC          8                48
# 4                                   Fəlsəfə          3                49
# 5                       Web texnologiyaları          4                48
# 6  Ehtimal nəzəriyyəsi və riyazi statistika          4                35
# 7            Paralel paylanmış hesablamalar          4                35
#
#          Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  Unnamed: 7
# 1  İmtahandan sonra      Yekun     Hərflə   Ortalama  Stipendiya
# 2                45         91          A      21.23    Zerbechi
# 3                47         95          A      25.33    Zerbechi
# 4                41         90          B          9    Zerbechi
# ...

# %%
data.columns=data.iloc[0]
data=data[1:]
data
# Out:
# 1                                    Fənlər Kredit İmtahandan əvvəl  \
# 2                    Sistem proqramlaşdırma      7               46
# 3                                       HPC      8               48
# 4                                   Fəlsəfə      3               49
# 5                       Web texnologiyaları      4               48
# 6  Ehtimal nəzəriyyəsi və riyazi statistika      4               35
# 7            Paralel paylanmış hesablamalar      4               35
#
# 1 İmtahandan sonra Yekun Hərflə Ortalama Stipendiya
# 2               45    91      A    21.23   Zerbechi
# 3               47    95      A    25.33   Zerbechi
# 4               41    90      B        9   Zerbechi
# 5               43    91      A    12.13   Zerbechi
# 6               39    74      C     9.87   Zerbechi
# 7               36    71      C     9.47   Zerbechi

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6 entries, 2 to 7
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Fənlər            6 non-null      object
#  1   Kredit            6 non-null      object
#  2   İmtahandan əvvəl  6 non-null      object
#  3   İmtahandan sonra  6 non-null      object
#  4   Yekun             6 non-null      object
#  5   Hərflə            6 non-null      object
#  6   Ortalama          6 non-null      object
#  7   Stipendiya        6 non-null      object
# dtypes: object(8)
# memory usage: 432.0+ bytes

# %%
data['Kredit'].astype(int)
data['İmtahandan əvvəl'].astype(int)
data['İmtahandan sonra'].astype(int)
data['Yekun'].astype(int)
data['Ortalama'].astype(float)
# Out:
# 2    21.23
# 3    25.33
# 4     9.00
# 5    12.13
# 6     9.87
# 7     9.47
# Name: Ortalama, dtype: float64

# %%
data
# Out:
# 1                                    Fənlər Kredit İmtahandan əvvəl  \
# 2                    Sistem proqramlaşdırma      7               46
# 3                                       HPC      8               48
# 4                                   Fəlsəfə      3               49
# 5                       Web texnologiyaları      4               48
# 6  Ehtimal nəzəriyyəsi və riyazi statistika      4               35
# 7            Paralel paylanmış hesablamalar      4               35
#
# 1 İmtahandan sonra Yekun Hərflə Ortalama Stipendiya
# 2               45    91      A    21.23   Zerbechi
# 3               47    95      A    25.33   Zerbechi
# 4               41    90      B        9   Zerbechi
# 5               43    91      A    12.13   Zerbechi
# 6               39    74      C     9.87   Zerbechi
# 7               36    71      C     9.47   Zerbechi

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6 entries, 2 to 7
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Fənlər            6 non-null      object
#  1   Kredit            6 non-null      object
#  2   İmtahandan əvvəl  6 non-null      object
#  3   İmtahandan sonra  6 non-null      object
#  4   Yekun             6 non-null      object
#  5   Hərflə            6 non-null      object
#  6   Ortalama          6 non-null      object
#  7   Stipendiya        6 non-null      object
# dtypes: object(8)
# memory usage: 432.0+ bytes

# %%
data['Ortalama'].mean()
# Out:
# 14.505

# %%
import seaborn as sea
sea.barplot(data,x='İmtahandan əvvəl',y='İmtahandan sonra',color='hotpink',width=0.5)
# Out:
# <Axes: xlabel='İmtahandan əvvəl', ylabel='İmtahandan sonra'>

# %%
import matplotlib.pyplot as plt
data.plot()
plt.show()
